# %%
import os
import time

folder_path = r"C:\Users\NITRO V\OneDrive\Desktop\Rice_Bran_Infer\25%"

for filename in os.listdir(folder_path):
    old_path = os.path.join(folder_path, filename)
    new_path = old_path + ".jpg"
    
    if not filename.lower().endswith(".jpg"):
        for attempt in range(5):
            try:
                os.rename(old_path, new_path)
                print(f"Renamed {filename} -> {filename}.jpg")
                break
            except PermissionError:
                print(f"File {filename} is in use, retrying...")
                time.sleep(1)
# Out:
# Renamed im_ 0x1g -> im_ 0x1g.jpg
# Renamed im_ 0x2g -> im_ 0x2g.jpg
# Renamed im_ 0x3g -> im_ 0x3g.jpg
# Renamed im_ 0x4g -> im_ 0x4g.jpg
# Renamed im_ 0x5g -> im_ 0x5g.jpg
# Renamed im_ 0x6g -> im_ 0x6g.jpg
# Renamed im_ 0x7g -> im_ 0x7g.jpg
# Renamed im_ 0x8g -> im_ 0x8g.jpg
# Renamed im_ 0x9g -> im_ 0x9g.jpg
# Renamed im_ 0xag -> im_ 0xag.jpg
# Renamed im_ 0xbg -> im_ 0xbg.jpg
# Renamed im_ 0xcg -> im_ 0xcg.jpg
# Renamed im_ 0xdg -> im_ 0xdg.jpg
# Renamed im_ 0xeg -> im_ 0xeg.jpg
# Renamed im_ 0xfg -> im_ 0xfg.jpg
# Renamed im_(nil)g -> im_(nil)g.jpg
# Renamed im_0x10g -> im_0x10g.jpg
# Renamed im_0x11g -> im_0x11g.jpg
# Renamed im_0x12g -> im_0x12g.jpg
# Renamed im_0x13g -> im_0x13g.jpg
# Renamed im_0x14g -> im_0x14g.jpg
# Renamed im_0x15g -> im_0x15g.jpg
# Renamed im_0x16g -> im_0x16g.jpg
# Renamed im_0x17g -> im_0x17g.jpg
# Renamed im_0x18g -> im_0x18g.jpg
# Renamed im_0x19g -> im_0x19g.jpg
# Renamed im_0x1ag -> im_0x1ag.jpg
# Renamed im_0x1bg -> im_0x1bg.jpg
# Renamed im_0x1cg -> im_0x1cg.jpg
# Renamed im_0x1dg -> im_0x1dg.jpg
# Renamed im_0x1eg -> im_0x1eg.jpg
# Renamed im_0x1fg -> im_0x1fg.jpg
# Renamed im_0x20g -> im_0x20g.jpg
# Renamed im_0x21g -> im_0x21g.jpg
# Renamed im_0x22g -> im_0x22g.jpg
# Renamed im_0x23g -> im_0x23g.jpg
# Renamed im_0x24g -> im_0x24g.jpg
# Renamed im_0x25g -> im_0x25g.jpg
# Renamed im_0x26g -> im_0x26g.jpg
# Renamed im_0x27g -> im_0x27g.jpg
# Renamed im_0x28g -> im_0x28g.jpg
# Renamed im_0x29g -> im_0x29g.jpg
